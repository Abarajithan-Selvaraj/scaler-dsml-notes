# %%
print("Welcome to Pandas-3")
# Out:
# Welcome to Pandas-3

# %% [markdown]
# # Agenda
#
# - **Concatenation**✅
#     - `pd.concat()`✅
#     - `axis` for concat✅
#
# - **Merge**✅
#     - Concat v/s Merge✅
#     - `left_on` and `right_on`✅
#     - Joins✅
#
#
# - **Intoduction to IMDB dataset**✅
#     - Reading two datasets✅
#
#
# - **Merging the dataframes**✅
#     - `unique()` and `nunique()`✅
#     - `isin()`✅
#     - Using Left Join for `merge()`✅
#
#
# - **Feature Exploration**✅
#     - Create new features✅
#
#
# - **Fetching data using pandas**✅
#     - Quering from dataframe - Masking, Filtering, `&` and `|`✅
#
#
# - **Apply**✅

# %%
import pandas as pd 
import numpy as np

# %%
users=pd.DataFrame({"user_id":[1,2,3],"name":["Tarun","Tanya","Rahul"]})
users
# Out:
#    user_id   name
# 0        1  Tarun
# 1        2  Tanya
# 2        3  Rahul

# %%
messages=pd.DataFrame({"user_id":[1,1,2,4],"msg":["hmm","acha","theek_hai","nice"]})
messages
# Out:
#    user_id        msg
# 0        1        hmm
# 1        1       acha
# 2        2  theek_hai
# 3        4       nice

# %%
pd.concat([users,messages])
# Out:
#    user_id   name        msg
# 0        1  Tarun        NaN
# 1        2  Tanya        NaN
# 2        3  Rahul        NaN
# 0        1    NaN        hmm
# 1        1    NaN       acha
# 2        2    NaN  theek_hai
# 3        4    NaN       nice

# %%
pd.concat([users,messages],axis=1)
# Out:
#    user_id   name  user_id        msg
# 0      1.0  Tarun        1        hmm
# 1      2.0  Tanya        1       acha
# 2      3.0  Rahul        2  theek_hai
# 3      NaN    NaN        4       nice

# %%
type(np.nan)
# Out:
# float

# %%
# pd.merge(left, right, on,how)
# left.merge(right,on,how)

# %%
users
# Out:
#    user_id   name
# 0        1  Tarun
# 1        2  Tanya
# 2        3  Rahul

# %%
messages
# Out:
#    user_id        msg
# 0        1        hmm
# 1        1       acha
# 2        2  theek_hai
# 3        4       nice

# %%
pd.merge(users, messages, how="left")
# Out:
#    user_id   name        msg
# 0        1  Tarun        hmm
# 1        1  Tarun       acha
# 2        2  Tanya  theek_hai
# 3        3  Rahul        NaN

# %%
users.merge(messages,on="user_id",how="left")
# Out:
#    user_id   name        msg
# 0        1  Tarun        hmm
# 1        1  Tarun       acha
# 2        2  Tanya  theek_hai
# 3        3  Rahul        NaN

# %%
users.merge(messages,on="user_id",how="inner")
# Out:
#    user_id   name        msg
# 0        1  Tarun        hmm
# 1        1  Tarun       acha
# 2        2  Tanya  theek_hai

# %%
users.merge(messages,on="user_id",how="right")
# Out:
#    user_id   name        msg
# 0        1  Tarun        hmm
# 1        1  Tarun       acha
# 2        2  Tanya  theek_hai
# 3        4    NaN       nice

# %%
users.merge(messages,on="user_id",how="outer")
# Out:
#    user_id   name        msg
# 0        1  Tarun        hmm
# 1        1  Tarun       acha
# 2        2  Tanya  theek_hai
# 3        3  Rahul        NaN
# 4        4    NaN       nice

# %%
messages.rename(columns={"user_id":"id"},inplace=True)

# %%
users
# Out:
#    user_id   name
# 0        1  Tarun
# 1        2  Tanya
# 2        3  Rahul

# %%
messages
# Out:
#    id        msg
# 0   1        hmm
# 1   1       acha
# 2   2  theek_hai
# 3   4       nice

# %%
users.merge(messages,left_on="user_id",right_on="id",how="left")
# Out:
#    user_id   name   id        msg
# 0        1  Tarun  1.0        hmm
# 1        1  Tarun  1.0       acha
# 2        2  Tanya  2.0  theek_hai
# 3        3  Rahul  NaN        NaN

# %%
pd.merge(users,messages,left_on="user_id",right_on="id",how="left")
# Out:
#    user_id   name   id        msg
# 0        1  Tarun  1.0        hmm
# 1        1  Tarun  1.0       acha
# 2        2  Tanya  2.0  theek_hai
# 3        3  Rahul  NaN        NaN

# %%
pd.merge(users,messages,left_on="user_id",right_on="id",how="inner")
# Out:
#    user_id   name  id        msg
# 0        1  Tarun   1        hmm
# 1        1  Tarun   1       acha
# 2        2  Tanya   2  theek_hai

# %%
pd.merge(messages,users,left_on="id",right_on="user_id",how="inner")
# Out:
#    id        msg  user_id   name
# 0   1        hmm        1  Tarun
# 1   1       acha        1  Tarun
# 2   2  theek_hai        2  Tanya

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /Users/nikhilsanghi/Downloads/01_dsml-course-main-live/batches/1_Aug_Beg_Mon/11_Pandas_3/movies.csv
# 100%|█████████████████████████████████████████| 112k/112k [00:00<00:00, 675kB/s]

# %%
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /Users/nikhilsanghi/Downloads/01_dsml-course-main-live/batches/1_Aug_Beg_Mon/11_Pandas_3/directors.csv
# 100%|███████████████████████████████████████| 65.4k/65.4k [00:00<00:00, 503kB/s]

# %%
movies=pd.read_csv("/Users/nikhilsanghi/Downloads/01_dsml-course-main-live/batches/1_Aug_Beg_Mon/11_Pandas_3/movies.csv")
movies.drop(columns=["Unnamed: 0"],inplace=True)
movies
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
directors=pd.read_csv("/Users/nikhilsanghi/Downloads/01_dsml-course-main-live/batches/1_Aug_Beg_Mon/11_Pandas_3/directors.csv")
directors.drop(columns=["Unnamed: 0"],inplace=True)
directors
# Out:
#           director_name    id gender
# 0         James Cameron  4762   Male
# 1        Gore Verbinski  4763   Male
# 2            Sam Mendes  4764   Male
# 3     Christopher Nolan  4765   Male
# 4        Andrew Stanton  4766   Male
# ...                 ...   ...    ...
# 2344      Shane Carruth  7106   Male
# 2345   Neill Dela Llana  7107    NaN
# 2346        Scott Smith  7108    NaN
# 2347        Daniel Hsia  7109   Male
# 2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 3 columns]

# %%
# shape
# info
# describe
# head
# tail
# duplicates

# %%
directors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2349 entries, 0 to 2348
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   director_name  2349 non-null   object
#  1   id             2349 non-null   int64
#  2   gender         1724 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 55.2+ KB

# %%
movies["director_id"].nunique()
# Out:
# 199

# %%
directors["id"].nunique()
# Out:
# 2349

# %%
a=pd.Series(["a","b","c","a"])
b=pd.Series(["a","b"])

# %%
a
# Out:
# 0    a
# 1    b
# 2    c
# 3    a
# dtype: object

# %%
b
# Out:
# 0    a
# 1    b
# dtype: object

# %%
np.all(a.isin(b))
# Out:
# False

# %%
a.loc[a.isin(b)]
# Out:
# 0    a
# 1    b
# 3    a
# dtype: object

# %%
c=pd.Series(["a","b","a"])
d=pd.Series(["a","b","d","e","f"])
c.isin(d)
# Out:
# 0    True
# 1    True
# 2    True
# dtype: bool

# %%
np.all(c.isin(d))
# Out:
# True

# %%
movies.columns
# Out:
# Index(['id', 'budget', 'popularity', 'revenue', 'title', 'vote_average',
#        'vote_count', 'director_id', 'year', 'month', 'day'],
#       dtype='object')

# %%
directors.columns
# Out:
# Index(['director_name', 'id', 'gender'], dtype='object')

# %%
np.all(movies["director_id"].isin(directors["id"]))
# Out:
# True

# %%
df=movies.merge(directors,how="inner",left_on="director_id",right_on="id",suffixes=('_movie', '_director'))
df
# Out:
#       id_movie     budget  popularity     revenue                       title  \
# 0        43597  237000000         150  2787965087                      Avatar
# 1        43622  200000000         100  1845034188                     Titanic
# 2        43876  100000000         101   520000000  Terminator 2: Judgment Day
# 3        43879  115000000          38   378882411                   True Lies
# 4        44184   70000000          24    90000098                   The Abyss
# ...        ...        ...         ...         ...                         ...
# 1460     46859          0          14    25288872                 Enough Said
# 1461     47023    6500000          11    13368437          Friends with Money
# 1462     47524    3000000           5           0                 Please Give
# 1463     47962          0           0           0         Walking and Talking
# 1464     48229     250000           1     4186931            Lovely & Amazing
#
# ...

# %%
df.drop(columns=["id_director","director_id"],inplace=True)

# %%
df
# Out:
#       id_movie     budget  popularity     revenue                       title  \
# 0        43597  237000000         150  2787965087                      Avatar
# 1        43622  200000000         100  1845034188                     Titanic
# 2        43876  100000000         101   520000000  Terminator 2: Judgment Day
# 3        43879  115000000          38   378882411                   True Lies
# 4        44184   70000000          24    90000098                   The Abyss
# ...        ...        ...         ...         ...                         ...
# 1460     46859          0          14    25288872                 Enough Said
# 1461     47023    6500000          11    13368437          Friends with Money
# 1462     47524    3000000           5           0                 Please Give
# 1463     47962          0           0           0         Walking and Talking
# 1464     48229     250000           1     4186931            Lovely & Amazing
#
# ...

# %%
df.head()
# Out:
#    id_movie     budget  popularity     revenue                       title  \
# 0     43597  237000000         150  2787965087                      Avatar
# 1     43622  200000000         100  1845034188                     Titanic
# 2     43876  100000000         101   520000000  Terminator 2: Judgment Day
# 3     43879  115000000          38   378882411                   True Lies
# 4     44184   70000000          24    90000098                   The Abyss
#
#    vote_average  vote_count  year month        day  director_name gender
# 0           7.2       11800  2009   Dec   Thursday  James Cameron   Male
# 1           7.5        7562  1997   Nov    Tuesday  James Cameron   Male
# 2           7.7        4185  1991   Jul     Monday  James Cameron   Male
# 3           6.8        1116  1994   Jul   Thursday  James Cameron   Male
# 4           7.1         808  1989   Aug  Wednesday  James Cameron   Male

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_movie       1465 non-null   int64
#  1   budget         1465 non-null   int64
#  2   popularity     1465 non-null   int64
#  3   revenue        1465 non-null   int64
#  4   title          1465 non-null   object
#  5   vote_average   1465 non-null   float64
#  6   vote_count     1465 non-null   int64
#  7   year           1465 non-null   int64
#  8   month          1465 non-null   object
#  9   day            1465 non-null   object
#  10  director_name  1465 non-null   object
#  11  gender         1341 non-null   object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 148.8+ KB

# %%
df.describe(include="all")
# Out:
#             id_movie        budget   popularity       revenue   title  \
# count    1465.000000  1.465000e+03  1465.000000  1.465000e+03    1465
# unique           NaN           NaN          NaN           NaN    1465
# top              NaN           NaN          NaN           NaN  Avatar
# freq             NaN           NaN          NaN           NaN       1
# mean    45225.191126  4.802295e+07    30.855973  1.432539e+08     NaN
# std      1189.096396  4.935541e+07    34.845214  2.064918e+08     NaN
# min     43597.000000  0.000000e+00     0.000000  0.000000e+00     NaN
# 25%     44236.000000  1.400000e+07    11.000000  1.738013e+07     NaN
# 50%     45022.000000  3.300000e+07    23.000000  7.578164e+07     NaN
# 75%     45990.000000  6.600000e+07    41.000000  1.792469e+08     NaN
# max     48395.000000  3.800000e+08   724.000000  2.787965e+09     NaN
#
#         vote_average    vote_count         year month     day  \
# count    1465.000000   1465.000000  1465.000000  1465    1465
# ...

# %%
df.head()
# Out:
#    id_movie     budget  popularity     revenue                       title  \
# 0     43597  237000000         150  2787965087                      Avatar
# 1     43622  200000000         100  1845034188                     Titanic
# 2     43876  100000000         101   520000000  Terminator 2: Judgment Day
# 3     43879  115000000          38   378882411                   True Lies
# 4     44184   70000000          24    90000098                   The Abyss
#
#    vote_average  vote_count  year month        day  director_name gender
# 0           7.2       11800  2009   Dec   Thursday  James Cameron   Male
# 1           7.5        7562  1997   Nov    Tuesday  James Cameron   Male
# 2           7.7        4185  1991   Jul     Monday  James Cameron   Male
# 3           6.8        1116  1994   Jul   Thursday  James Cameron   Male
# 4           7.1         808  1989   Aug  Wednesday  James Cameron   Male

# %%
df["budget"]=(df["budget"]/1000000).round(2)

# %%
df.head()
# Out:
#    id_movie  budget  popularity     revenue                       title  \
# 0     43597   237.0         150  2787965087                      Avatar
# 1     43622   200.0         100  1845034188                     Titanic
# 2     43876   100.0         101   520000000  Terminator 2: Judgment Day
# 3     43879   115.0          38   378882411                   True Lies
# 4     44184    70.0          24    90000098                   The Abyss
#
#    vote_average  vote_count  year month        day  director_name gender
# 0           7.2       11800  2009   Dec   Thursday  James Cameron   Male
# 1           7.5        7562  1997   Nov    Tuesday  James Cameron   Male
# 2           7.7        4185  1991   Jul     Monday  James Cameron   Male
# 3           6.8        1116  1994   Jul   Thursday  James Cameron   Male
# 4           7.1         808  1989   Aug  Wednesday  James Cameron   Male

# %%
df["revenue"]=(df["revenue"]/1000000).round(2)

# %%
df.head()
# Out:
#    id_movie  budget  popularity  revenue                       title  \
# 0     43597   237.0         150  2787.97                      Avatar
# 1     43622   200.0         100  1845.03                     Titanic
# 2     43876   100.0         101   520.00  Terminator 2: Judgment Day
# 3     43879   115.0          38   378.88                   True Lies
# 4     44184    70.0          24    90.00                   The Abyss
#
#    vote_average  vote_count  year month        day  director_name gender
# 0           7.2       11800  2009   Dec   Thursday  James Cameron   Male
# 1           7.5        7562  1997   Nov    Tuesday  James Cameron   Male
# 2           7.7        4185  1991   Jul     Monday  James Cameron   Male
# 3           6.8        1116  1994   Jul   Thursday  James Cameron   Male
# 4           7.1         808  1989   Aug  Wednesday  James Cameron   Male

# %%
df.rename(columns={"budget":"budget_mil","revenue":"revenue_mil"},inplace=True)

# %%
df.head()
# Out:
#    id_movie  budget_mil  popularity  revenue_mil                       title  \
# 0     43597       237.0         150      2787.97                      Avatar
# 1     43622       200.0         100      1845.03                     Titanic
# 2     43876       100.0         101       520.00  Terminator 2: Judgment Day
# 3     43879       115.0          38       378.88                   True Lies
# 4     44184        70.0          24        90.00                   The Abyss
#
#    vote_average  vote_count  year month        day  director_name gender
# 0           7.2       11800  2009   Dec   Thursday  James Cameron   Male
# 1           7.5        7562  1997   Nov    Tuesday  James Cameron   Male
# 2           7.7        4185  1991   Jul     Monday  James Cameron   Male
# 3           6.8        1116  1994   Jul   Thursday  James Cameron   Male
# 4           7.1         808  1989   Aug  Wednesday  James Cameron   Male

# %%
# I want to find out all the highly rated movies
# highly rated movies ~ all the movies which are rated 7+(>7)

# %%
df["vote_average"]>7
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: vote_average, Length: 1465, dtype: bool

# %%
df.loc[df["vote_average"]>7]
# Out:
#       id_movie  budget_mil  popularity  revenue_mil  \
# 0        43597      237.00         150      2787.97
# 1        43622      200.00         100      1845.03
# 2        43876      100.00         101       520.00
# 4        44184       70.00          24        90.00
# 5        46000       18.50          67       183.32
# ...        ...         ...         ...          ...
# 1424     47488        4.00          11        35.56
# 1426     48310        0.16           3         6.71
# 1433     46168       11.50          15        23.24
# 1438     47597        0.00          11         0.00
# 1441     47232        5.00          35         8.20
#
#                            title  vote_average  vote_count  year month  \
# 0                         Avatar           7.2       11800  2009   Dec
# 1                        Titanic           7.5        7562  1997   Nov
# 2     Terminator 2: Judgment Day           7.7        4185  1991   Jul
# ...

# %%
df[df["vote_average"]>7]
# Out:
#       id_movie  budget_mil  popularity  revenue_mil  \
# 0        43597      237.00         150      2787.97
# 1        43622      200.00         100      1845.03
# 2        43876      100.00         101       520.00
# 4        44184       70.00          24        90.00
# 5        46000       18.50          67       183.32
# ...        ...         ...         ...          ...
# 1424     47488        4.00          11        35.56
# 1426     48310        0.16           3         6.71
# 1433     46168       11.50          15        23.24
# 1438     47597        0.00          11         0.00
# 1441     47232        5.00          35         8.20
#
#                            title  vote_average  vote_count  year month  \
# 0                         Avatar           7.2       11800  2009   Dec
# 1                        Titanic           7.5        7562  1997   Nov
# 2     Terminator 2: Judgment Day           7.7        4185  1991   Jul
# ...

# %%
df.loc[df["vote_average"]>7].sort_values(by=["vote_average"],ascending=False)
# Out:
#       id_movie  budget_mil  popularity  revenue_mil  \
# 305      44259        63.0         146       100.85
# 205      45415        22.0         104       321.37
# 653      46829         8.0         121       213.93
# 22       43662       185.0         187      1004.56
# 230      44406        55.0         138       677.95
# ...        ...         ...         ...          ...
# 1250     47612         2.5          10         0.00
# 1285     46512         0.0          14         0.00
# 252      43913       100.0          46       193.77
# 233      44762        40.0          45       244.53
# 677      46460         0.0          21        92.86
#
#                             title  vote_average  vote_count  year month  \
# 305                    Fight Club           8.3        9413  1999   Oct
# 205              Schindler's List           8.3        4329  1993   Nov
# 653                  Pulp Fiction           8.3        8428  1994   Oct
# ...

# %%
# Top 5 most popular movies

# %%
df.sort_values(by=["popularity"],ascending=False).head()
# Out:
#      id_movie  budget_mil  popularity  revenue_mil  \
# 23      43692       165.0         724       675.12
# 361     43724       150.0         434       378.86
# 11      43796       140.0         271       655.01
# 315     43797       125.0         206       752.10
# 22      43662       185.0         187      1004.56
#
#                                                  title  vote_average  \
# 23                                        Interstellar           8.1
# 361                                 Mad Max: Fury Road           7.2
# 11   Pirates of the Caribbean: The Curse of the Bla...           7.5
# 315              The Hunger Games: Mockingjay - Part 1           6.6
# 22                                     The Dark Knight           8.2
#
#      vote_count  year month        day      director_name gender
# 23        10867  2014   Nov  Wednesday  Christopher Nolan   Male
# 361        9427  2015   May  Wednesday      George Miller   Male
# ...

# %%
# I just want to find out latest highly rated movies
# highly rated movies ~ vote_average >7
# latest ~ movies released after 2014

# %%
(df["vote_average"]>7) & (df["year"]>2014)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Length: 1465, dtype: bool

# %%
df.loc[(df["vote_average"]>7) & (df["year"]>2014)]
# Out:
#      id_movie  budget_mil  popularity  revenue_mil                    title  \
# 93      43867       108.0         167       630.16              The Martian
# 166     43641       190.0         102      1506.25                Furious 7
# 201     44784        40.0          48       165.48          Bridge of Spies
# 361     43724       150.0         434       378.86       Mad Max: Fury Road
# 465     43773       135.0         100       532.95             The Revenant
# 512     44128        75.0          48       108.15  The Man from U.N.C.L.E.
# 639     45301        28.0          57       133.35            The Big Short
# 649     44281        44.0          68       155.76        The Hateful Eight
# 766     44770        35.0          53       194.56               The Intern
# 818     47181         5.0          22        24.80                     Race
# 853     45293        28.0          61       201.63   Straight Outta Compton
# ...

# %%
# I want to find out movies released on Friday or Saturday

# %%
(df["day"]=="Friday") | (df["day"]=="Saturday")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462     True
# 1463    False
# 1464     True
# Name: day, Length: 1465, dtype: bool

# %%
df.loc[(df["day"]=="Friday") | (df["day"]=="Saturday") ]
# Out:
#       id_movie  budget_mil  popularity  revenue_mil  \
# 5        46000       18.50          67       183.32
# 6        47036        6.40          74        78.37
# 7        43598      300.00         139       961.00
# 16       44041       80.00          49       181.00
# 17       44154       72.00          32        96.89
# ...        ...         ...         ...          ...
# 1455     46574       10.00          33       163.88
# 1457     46827        0.00           5         0.19
# 1458     47152        4.00          42       152.93
# 1462     47524        3.00           5         0.00
# 1464     48229        0.25           1         4.19
#
#                                          title  vote_average  vote_count  \
# 5                                       Aliens           7.7        3220
# 6                               The Terminator           7.3        4128
# 7     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
# I want to find out movies released on Friday or Saturday or Monday or Tuesday

# %%
days_concerned=pd.Series(["Friday","Saturday","Monday","Tuesday"])
days_concerned
# Out:
# 0      Friday
# 1    Saturday
# 2      Monday
# 3     Tuesday
# dtype: object

# %%
df["day"].isin(days_concerned)
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462     True
# 1463    False
# 1464     True
# Name: day, Length: 1465, dtype: bool

# %%
df.loc[df["day"].isin(days_concerned)]
# Out:
#       id_movie  budget_mil  popularity  revenue_mil  \
# 1        43622      200.00         100      1845.03
# 2        43876      100.00         101       520.00
# 5        46000       18.50          67       183.32
# 6        47036        6.40          74        78.37
# 7        43598      300.00         139       961.00
# ...        ...         ...         ...          ...
# 1457     46827        0.00           5         0.19
# 1458     47152        4.00          42       152.93
# 1459     48155        0.00           0         0.00
# 1462     47524        3.00           5         0.00
# 1464     48229        0.25           1         4.19
#
#                                          title  vote_average  vote_count  \
# 1                                      Titanic           7.5        7562
# 2                   Terminator 2: Judgment Day           7.7        4185
# 5                                       Aliens           7.7        3220
# ...

# %%
df.columns
# Out:
# Index(['id_movie', 'budget_mil', 'popularity', 'revenue_mil', 'title',
#        'vote_average', 'vote_count', 'year', 'month', 'day', 'director_name',
#        'gender'],
#       dtype='object')

# %%
# I want to find out all the movies directed by "Christopher Nolan"

# %%
df["director_name"]=="Christopher Nolan"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: director_name, Length: 1465, dtype: bool

# %%
df.loc[df["director_name"]=="Christopher Nolan"]
# Out:
#     id_movie  budget_mil  popularity  revenue_mil                  title  \
# 21     43600       250.0         112      1084.94  The Dark Knight Rises
# 22     43662       185.0         187      1004.56        The Dark Knight
# 23     43692       165.0         724       675.12           Interstellar
# 24     43693       160.0         167       825.53              Inception
# 25     43716       150.0         115       374.22          Batman Begins
# 26     44630        46.0          41       113.71               Insomnia
# 27     44793        40.0          74       109.68           The Prestige
# 28     47170         9.0          60        39.72                Memento
#
#     vote_average  vote_count  year month        day      director_name gender
# 21           7.6        9106  2012   Jul     Monday  Christopher Nolan   Male
# 22           8.2       12002  2008   Jul  Wednesday  Christopher Nolan   Male
# 23           8.1       10867  2014   Nov  Wednesday  Christopher Nolan   Male
# ...

# %%
# I want to find out all the highest rated movies year wise( 2016--> )

# %%
df2=df.sort_values(by=["year","vote_average"],ascending=[False,False])
df2
# Out:
#       id_movie  budget_mil  popularity  revenue_mil  \
# 818      47181         5.0          22        24.80
# 149      44538        50.0          42        69.41
# 167      44757        40.0          68       320.17
# 244      43675       175.0          94       966.55
# 450      43967        90.0          51       334.90
# ...        ...         ...         ...          ...
# 1168     48095         0.6          10         0.00
# 262      46290         0.0           3         0.00
# 265      47934         1.3          58        28.26
# 1415     47409         3.8          17        23.69
# 439      45435         2.8          25        60.92
#
#                                           title  vote_average  vote_count  \
# 818                                        Race           7.1         478
# 149   13 Hours: The Secret Soldiers of Benghazi           7.0         938
# 167                             The Conjuring 2           7.0        1949
# ...

# %%
df2.drop_duplicates(subset=["year"],keep="first")
# Out:
#       id_movie  budget_mil  popularity  revenue_mil  \
# 818      47181         5.0          22        24.80
# 853      45293        28.0          61       201.63
# 23       43692       165.0         724       675.12
# 251      43895       100.0          95       392.00
# 647      43884       100.0          82       425.37
# 558      48068         0.0           5         0.00
# 24       43693       160.0         167       825.53
# 648      44168        70.0          72       319.13
# 22       43662       185.0         187      1004.56
# 1301     45452        25.0          37        77.21
# 27       44793        40.0          74       109.68
# 407      45321        28.0          36       121.15
# 946      45154        30.0          70       216.76
# 86       43926        94.0         123      1118.89
# 87       43927        79.0         106       926.29
# 84       43859        93.0         138       871.37
# 28       47170         9.0          60        39.72
# ...

# %%
# df.groupby

# %%
# .apply

# %%
df.head()
# Out:
#    id_movie  budget_mil  popularity  revenue_mil                       title  \
# 0     43597       237.0         150      2787.97                      Avatar
# 1     43622       200.0         100      1845.03                     Titanic
# 2     43876       100.0         101       520.00  Terminator 2: Judgment Day
# 3     43879       115.0          38       378.88                   True Lies
# 4     44184        70.0          24        90.00                   The Abyss
#
#    vote_average  vote_count  year month        day  director_name gender
# 0           7.2       11800  2009   Dec   Thursday  James Cameron   Male
# 1           7.5        7562  1997   Nov    Tuesday  James Cameron   Male
# 2           7.7        4185  1991   Jul     Monday  James Cameron   Male
# 3           6.8        1116  1994   Jul   Thursday  James Cameron   Male
# 4           7.1         808  1989   Aug  Wednesday  James Cameron   Male

# %%
df["gender"].unique()
# Out:
# array(['Male', nan, 'Female'], dtype=object)

# %%
def custom_func(x):
    if x=="Male":
        return 0
    else:
        return 1

# %%
df["gender"]=df["gender"].apply(custom_func)

# %%
df.apply?

# %%
df
# Out:
#       id_movie  budget_mil  popularity  revenue_mil  \
# 0        43597      237.00         150      2787.97
# 1        43622      200.00         100      1845.03
# 2        43876      100.00         101       520.00
# 3        43879      115.00          38       378.88
# 4        44184       70.00          24        90.00
# ...        ...         ...         ...          ...
# 1460     46859        0.00          14        25.29
# 1461     47023        6.50          11        13.37
# 1462     47524        3.00           5         0.00
# 1463     47962        0.00           0         0.00
# 1464     48229        0.25           1         4.19
#
#                            title  vote_average  vote_count  year month  \
# 0                         Avatar           7.2       11800  2009   Dec
# 1                        Titanic           7.5        7562  1997   Nov
# 2     Terminator 2: Judgment Day           7.7        4185  1991   Jul
# ...

# %%
df[["budget_mil","revenue_mil"]]
# Out:
#       budget_mil  revenue_mil
# 0         237.00      2787.97
# 1         200.00      1845.03
# 2         100.00       520.00
# 3         115.00       378.88
# 4          70.00        90.00
# ...          ...          ...
# 1460        0.00        25.29
# 1461        6.50        13.37
# 1462        3.00         0.00
# 1463        0.00         0.00
# 1464        0.25         4.19
#
# [1465 rows x 2 columns]

# %%
df.apply?

# %%
df[["budget_mil","revenue_mil"]].apply(np.sum)
# Out:
# budget_mil      70353.62
# revenue_mil    209867.04
# dtype: float64

# %%
df["budget+revenue"]=df[["budget_mil","revenue_mil"]].apply(np.sum,axis=1)

# %%
df
# Out:
#       id_movie  budget_mil  popularity  revenue_mil  \
# 0        43597      237.00         150      2787.97
# 1        43622      200.00         100      1845.03
# 2        43876      100.00         101       520.00
# 3        43879      115.00          38       378.88
# 4        44184       70.00          24        90.00
# ...        ...         ...         ...          ...
# 1460     46859        0.00          14        25.29
# 1461     47023        6.50          11        13.37
# 1462     47524        3.00           5         0.00
# 1463     47962        0.00           0         0.00
# 1464     48229        0.25           1         4.19
#
#                            title  vote_average  vote_count  year month  \
# 0                         Avatar           7.2       11800  2009   Dec
# 1                        Titanic           7.5        7562  1997   Nov
# 2     Terminator 2: Judgment Day           7.7        4185  1991   Jul
# ...

# %%
def profit_func(x):
    return x["revenue_mil"]-x["budget_mil"]

# %%
df["profit"]=df.apply(profit_func,axis=1)

# %%
df
# Out:
#       id_movie  budget_mil  popularity  revenue_mil  \
# 0        43597      237.00         150      2787.97
# 1        43622      200.00         100      1845.03
# 2        43876      100.00         101       520.00
# 3        43879      115.00          38       378.88
# 4        44184       70.00          24        90.00
# ...        ...         ...         ...          ...
# 1460     46859        0.00          14        25.29
# 1461     47023        6.50          11        13.37
# 1462     47524        3.00           5         0.00
# 1463     47962        0.00           0         0.00
# 1464     48229        0.25           1         4.19
#
#                            title  vote_average  vote_count  year month  \
# 0                         Avatar           7.2       11800  2009   Dec
# 1                        Titanic           7.5        7562  1997   Nov
# 2     Terminator 2: Judgment Day           7.7        4185  1991   Jul
# ...

# %%
# def profit_func(x):
#     return x["revenue_mil"]-x["budget_mil"]

# %%
# df["profit1"]=df.apply(profit_func,axis=1)

# %%
# df.columns

# %%
# !gdown 1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# To: /Users/nikhilsanghi/Downloads/01_dsml-course-main-live/batches/1_Aug_Beg_Mon/11_Pandas_3/mckinsey.csv
# 100%|██████████████████████████████████████| 83.8k/83.8k [00:00<00:00, 1.23MB/s]

# %%
df=pd.read_csv("mckinsey.csv")
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.describe()
# Out:
#              year    population     life_exp        gdp_cap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
df.describe(include="all")
# Out:
#             country        year    population continent     life_exp  \
# count          1704  1704.00000  1.704000e+03      1704  1704.000000
# unique          142         NaN           NaN         5          NaN
# top     Afghanistan         NaN           NaN    Africa          NaN
# freq             12         NaN           NaN       624          NaN
# mean            NaN  1979.50000  2.960121e+07       NaN    59.474439
# std             NaN    17.26533  1.061579e+08       NaN    12.917107
# min             NaN  1952.00000  6.001100e+04       NaN    23.599000
# 25%             NaN  1965.75000  2.793664e+06       NaN    48.198000
# 50%             NaN  1979.50000  7.023596e+06       NaN    60.712500
# 75%             NaN  1993.25000  1.958522e+07       NaN    70.845500
# max             NaN  2007.00000  1.318683e+09       NaN    82.603000
#
#               gdp_cap
# count     1704.000000
# unique            NaN
# top               NaN
# freq              NaN
# ...

# %%
df["continent"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
df["continent"].nunique()
# Out:
# 5

# %%
df["continent"].value_counts()
# Out:
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: continent, dtype: int64
